# %%
import os
import csv
import json
import numpy as np
from typing import List, Optional, Tuple
from sklearn.neighbors import NearestNeighbors
import joblib


def build_knn_from_csv(csv_path: str, vector_col: str = "genre_vector", metric: str = "cosine") -> Tuple[NearestNeighbors, np.ndarray, List[str], np.ndarray]:
    if not os.path.exists(csv_path):
        raise FileNotFoundError(csv_path)
    with open(csv_path, "r", encoding="utf-8-sig", newline="") as f:
        reader = csv.reader(f)
        rows = list(reader)
    if not rows or len(rows) < 2:
        raise ValueError("CSV has no data rows")

    header = rows[0]
    data_rows = rows[1:]

    vec_idx = _find_col_idx(header, [vector_col])
    if vec_idx is None:
        raise ValueError(f"Vector column not found: {vector_col}")

    title_idx = _find_col_idx(header, ["title", "song", "name", "track", "곡명", "제목"])
    titles: List[str] = [r[title_idx] if (title_idx is not None and title_idx < len(r)) else str(i) for i, r in enumerate(data_rows)]

    vectors: List[Optional[List[float]]] = []
    for r in data_rows:
        cell = r[vec_idx] if vec_idx < len(r) else ""
        vectors.append(_parse_json_vector(cell))

    dim = 0
    for v in vectors:
        if isinstance(v, list) and len(v) > 0:
            dim = len(v)
            break
    if dim == 0:
        raise ValueError("No valid vectors")

    M = np.zeros((len(vectors), dim), dtype=np.float32)
    valid = np.zeros((len(vectors),), dtype=bool)
    for i, v in enumerate(vectors):
        if isinstance(v, list) and len(v) == dim:
            M[i, :] = np.asarray(v, dtype=np.float32)
            valid[i] = True

    if not valid.any():
        raise ValueError("No valid rows for KNN")

    nn = NearestNeighbors(metric=metric, algorithm="brute")
    nn.fit(M[valid])
    return nn, M, titles, valid


def save_knn_model(model_path: str, nn: NearestNeighbors, matrix: np.ndarray, titles: List[str], valid_mask: np.ndarray, vector_col: str = "genre_vector") -> None:
    payload = {
        "vector_col": vector_col,
        "titles": titles,
        "valid_mask": valid_mask,
        "matrix": matrix,
        "nn_model": nn,
    }
    joblib.dump(payload, model_path)


# Example usage (adjust paths as needed)
try:
    nn_model, M_all, song_titles, valid_mask = build_knn_from_csv(CSV_PATH, vector_col="genre_vector", metric="cosine")
    MODEL_SAVE_PATH = "../models/knn_model.joblib"
    os.makedirs(os.path.dirname(MODEL_SAVE_PATH), exist_ok=True)
    save_knn_model(MODEL_SAVE_PATH, nn_model, M_all, song_titles, valid_mask, vector_col="genre_vector")
    print(f"[SAVE] KNN model saved to {MODEL_SAVE_PATH}")
except Exception as e:
    print(f"[ERROR] KNN save failed: {e}")

# %% [markdown]
# Genre.py는 csv파일에 있는 데이터를 기반으로 한다.
# 여기서 쓰이는 함수는 recommended_by_knn이다FAS
# csv 파일에 있는 음악 번호를 입력으로 받아서 그 음악을 좋아하는 사람의 장르와, 좋아하는 사람의 옷 스타일 태그를 집계해서 뽑아준다.
# 그 음악과 비슷한 공간에 있는 이웃 3명을 선택해서 스타일을 집계한 후 추천하는 시스템
#
# 웹에서 처음 사용자가 들어가서 옷을 3개 고르면 추엄 추천해주는 장르 추천시스템으로 쓰일것
# --> 여기서 사용자가 옷을 선택하면 그 데이터를 저장해서 Fashion clip의 학습 데이터로 사용할 수 있게 데모 서버를 만들어야할 것 같다.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install laion-clap torch torchaudio soundfile librosa
# !pip install torch torchaudio --index-url https://download.pytorch.org/whl/cpu
# Out:
# Collecting laion-clap
#   Downloading laion_clap-1.1.7-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.12/dist-packages (0.13.1)
# Requirement already satisfied: librosa in /usr/local/lib/python3.12/dist-packages (0.11.0)
# Collecting numpy<2.0.0,>=1.23.5 (from laion-clap)
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.1 MB/s eta 0:00:00
# Collecting torchlibrosa (from laion-clap)
#   Downloading torchlibrosa-0.1.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting ftfy (from laion-clap)
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting braceexpand (from laion-clap)
#   Downloading braceexpand-0.1.7-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting webdataset (from laion-clap)
#   Downloading webdataset-1.0.2-py3-none-any.whl.metadata (12 kB)
# Collecting wget (from laion-clap)
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: wandb in /usr/local/lib/python3.12/dist-packages (from laion-clap) (0.22.2)
# Requirement already satisfied: llvmlite in /usr/local/lib/python3.12/dist-packages (from laion-clap) (0.43.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from laion-clap) (1.16.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from laion-clap) (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from laion-clap) (2.2.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from laion-clap) (3.14.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from laion-clap) (4.67.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from laion-clap) (2024.11.6)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from laion-clap) (4.57.0)
# Collecting progressbar (from laion-clap)
#   Downloading progressbar-2.5.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile) (2.0.0)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.12/dist-packages (from librosa) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (0.60.0)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.5.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.0.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.12/dist-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.1.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile) (2.23)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from lazy_loader>=0.1->librosa) (25.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa) (4.5.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa) (2.32.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->laion-clap) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from ftfy->laion-clap) (0.2.14)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->laion-clap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->laion-clap) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->laion-clap) (2025.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers->laion-clap) (0.35.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers->laion-clap) (6.0.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers->laion-clap) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers->laion-clap) (0.6.2)
# Requirement already satisfied: click>=8.0.1 in /usr/local/lib/python3.12/dist-packages (from wandb->laion-clap) (8.3.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->laion-clap) (3.1.45)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from wandb->laion-clap) (5.29.5)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.12/dist-packages (from wandb->laion-clap) (2.11.10)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->laion-clap) (2.40.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb->laion-clap) (4.0.12)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers->laion-clap) (1.1.10)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb->laion-clap) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb->laion-clap) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb->laion-clap) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->laion-clap) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2025.10.5)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->laion-clap) (5.0.2)
# Downloading laion_clap-1.1.7-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 19.6 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 89.4 MB/s eta 0:00:00
# Downloading braceexpand-0.1.7-py2.py3-none-any.whl (5.9 kB)
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.3 MB/s eta 0:00:00
# Downloading torchlibrosa-0.1.0-py3-none-any.whl (11 kB)
# Downloading webdataset-1.0.2-py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 5.5 MB/s eta 0:00:00
# Building wheels for collected packages: progressbar, wget
#   Building wheel for progressbar (setup.py) ... done
#   Created wheel for progressbar: filename=progressbar-2.5-py3-none-any.whl size=12065 sha256=dc783ee048e8c678c7d1e01b8373e27e9f311f8335c4e459da14c8f38fefc9f6
#   Stored in directory: /root/.cache/pip/wheels/a5/4d/c7/f3cf0f75c746c219090060131fe00f1523cc2c5484991f4030
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9655 sha256=a3d7247022d76f79ceaca7d79c0001e3cd829f1bc292cea46f8fd0eddd74a416
#   Stored in directory: /root/.cache/pip/wheels/01/46/3b/e29ffbe4ebe614ff224bad40fc6a5773a67a163251585a13a9
# Successfully built progressbar wget
# Installing collected packages: wget, progressbar, braceexpand, numpy, ftfy, webdataset, torchlibrosa, laion-clap
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed braceexpand-0.1.7 ftfy-6.3.1 laion-clap-1.1.7 numpy-1.26.4 progressbar-2.5 torchlibrosa-0.1.0 webdataset-1.0.2 wget-3.2
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)

# %%
# 가사 입력
import numpy as np
import torch
import torch.nn.functional as F
import librosa
import os
import csv
import re
import json
from typing import List, Optional, Tuple, Dict
from laion_clap import CLAP_Module
# Out:
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/481 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]

# %%
# CLAP 모델 로드 (기본 사전학습 모델)
clap_model = CLAP_Module(enable_fusion=False)  # fusion=True 는 multi-modal fusion용
clap_model.load_ckpt()  # 자동으로 사전학습된 ckpt 로드
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/functional.py:554: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4322.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Load our best checkpoint in the paper.
# Downloading laion_clap weight files...
# Download completed!
# Load Checkpoint...
# logit_scale_a 	 Loaded
# logit_scale_t 	 Loaded
# audio_branch.spectrogram_extractor.stft.conv_real.weight 	 Loaded
# audio_branch.spectrogram_extractor.stft.conv_imag.weight 	 Loaded
# audio_branch.logmel_extractor.melW 	 Loaded
# audio_branch.bn0.weight 	 Loaded
# audio_branch.bn0.bias 	 Loaded
# audio_branch.patch_embed.proj.weight 	 Loaded
# audio_branch.patch_embed.proj.bias 	 Loaded
# audio_branch.patch_embed.norm.weight 	 Loaded
# audio_branch.patch_embed.norm.bias 	 Loaded
# audio_branch.layers.0.blocks.0.norm1.weight 	 Loaded
# audio_branch.layers.0.blocks.0.norm1.bias 	 Loaded
# audio_branch.layers.0.blocks.0.attn.relative_position_bias_table 	 Loaded
# audio_branch.layers.0.blocks.0.attn.qkv.weight 	 Loaded
# audio_branch.layers.0.blocks.0.attn.qkv.bias 	 Loaded
# audio_branch.layers.0.blocks.0.attn.proj.weight 	 Loaded
# audio_branch.layers.0.blocks.0.attn.proj.bias 	 Loaded
# audio_branch.layers.0.blocks.0.norm2.weight 	 Loaded
# audio_branch.layers.0.blocks.0.norm2.bias 	 Loaded
# audio_branch.layers.0.blocks.0.mlp.fc1.weight 	 Loaded
# audio_branch.layers.0.blocks.0.mlp.fc1.bias 	 Loaded
# audio_branch.layers.0.blocks.0.mlp.fc2.weight 	 Loaded
# audio_branch.layers.0.blocks.0.mlp.fc2.bias 	 Loaded
# audio_branch.layers.0.blocks.1.norm1.weight 	 Loaded
# audio_branch.layers.0.blocks.1.norm1.bias 	 Loaded
# audio_branch.layers.0.blocks.1.attn.relative_position_bias_table 	 Loaded
# audio_branch.layers.0.blocks.1.attn.qkv.weight 	 Loaded
# audio_branch.layers.0.blocks.1.attn.qkv.bias 	 Loaded
# audio_branch.layers.0.blocks.1.attn.proj.weight 	 Loaded
# audio_branch.layers.0.blocks.1.attn.proj.bias 	 Loaded
# audio_branch.layers.0.blocks.1.norm2.weight 	 Loaded
# audio_branch.layers.0.blocks.1.norm2.bias 	 Loaded
# audio_branch.layers.0.blocks.1.mlp.fc1.weight 	 Loaded
# audio_branch.layers.0.blocks.1.mlp.fc1.bias 	 Loaded
# audio_branch.layers.0.blocks.1.mlp.fc2.weight 	 Loaded
# audio_branch.layers.0.blocks.1.mlp.fc2.bias 	 Loaded
# audio_branch.layers.0.downsample.reduction.weight 	 Loaded
# audio_branch.layers.0.downsample.norm.weight 	 Loaded
# audio_branch.layers.0.downsample.norm.bias 	 Loaded
# audio_branch.layers.1.blocks.0.norm1.weight 	 Loaded
# audio_branch.layers.1.blocks.0.norm1.bias 	 Loaded
# audio_branch.layers.1.blocks.0.attn.relative_position_bias_table 	 Loaded
# audio_branch.layers.1.blocks.0.attn.qkv.weight 	 Loaded
# audio_branch.layers.1.blocks.0.attn.qkv.bias 	 Loaded
# audio_branch.layers.1.blocks.0.attn.proj.weight 	 Loaded
# audio_branch.layers.1.blocks.0.attn.proj.bias 	 Loaded
# audio_branch.layers.1.blocks.0.norm2.weight 	 Loaded
# audio_branch.layers.1.blocks.0.norm2.bias 	 Loaded
# audio_branch.layers.1.blocks.0.mlp.fc1.weight 	 Loaded
# audio_branch.layers.1.blocks.0.mlp.fc1.bias 	 Loaded
# audio_branch.layers.1.blocks.0.mlp.fc2.weight 	 Loaded
# audio_branch.layers.1.blocks.0.mlp.fc2.bias 	 Loaded
# audio_branch.layers.1.blocks.1.norm1.weight 	 Loaded
# audio_branch.layers.1.blocks.1.norm1.bias 	 Loaded
# audio_branch.layers.1.blocks.1.attn.relative_position_bias_table 	 Loaded
# audio_branch.layers.1.blocks.1.attn.qkv.weight 	 Loaded
# audio_branch.layers.1.blocks.1.attn.qkv.bias 	 Loaded
# audio_branch.layers.1.blocks.1.attn.proj.weight 	 Loaded
# audio_branch.layers.1.blocks.1.attn.proj.bias 	 Loaded
# audio_branch.layers.1.blocks.1.norm2.weight 	 Loaded
# audio_branch.layers.1.blocks.1.norm2.bias 	 Loaded
# audio_branch.layers.1.blocks.1.mlp.fc1.weight 	 Loaded
# audio_branch.layers.1.blocks.1.mlp.fc1.bias 	 Loaded
# audio_branch.layers.1.blocks.1.mlp.fc2.weight 	 Loaded
# audio_branch.layers.1.blocks.1.mlp.fc2.bias 	 Loaded
# audio_branch.layers.1.downsample.reduction.weight 	 Loaded
# audio_branch.layers.1.downsample.norm.weight 	 Loaded
# audio_branch.layers.1.downsample.norm.bias 	 Loaded
# audio_branch.layers.2.blocks.0.norm1.weight 	 Loaded
# audio_branch.layers.2.blocks.0.norm1.bias 	 Loaded
# audio_branch.layers.2.blocks.0.attn.relative_position_bias_table 	 Loaded
# audio_branch.layers.2.blocks.0.attn.qkv.weight 	 Loaded
# audio_branch.layers.2.blocks.0.attn.qkv.bias 	 Loaded
# audio_branch.layers.2.blocks.0.attn.proj.weight 	 Loaded
# audio_branch.layers.2.blocks.0.attn.proj.bias 	 Loaded
# audio_branch.layers.2.blocks.0.norm2.weight 	 Loaded
# audio_branch.layers.2.blocks.0.norm2.bias 	 Loaded
# audio_branch.layers.2.blocks.0.mlp.fc1.weight 	 Loaded
# audio_branch.layers.2.blocks.0.mlp.fc1.bias 	 Loaded
# audio_branch.layers.2.blocks.0.mlp.fc2.weight 	 Loaded
# audio_branch.layers.2.blocks.0.mlp.fc2.bias 	 Loaded
# audio_branch.layers.2.blocks.1.norm1.weight 	 Loaded
# audio_branch.layers.2.blocks.1.norm1.bias 	 Loaded
# audio_branch.layers.2.blocks.1.attn.relative_position_bias_table 	 Loaded
# audio_branch.layers.2.blocks.1.attn.qkv.weight 	 Loaded
# audio_branch.layers.2.blocks.1.attn.qkv.bias 	 Loaded
# audio_branch.layers.2.blocks.1.attn.proj.weight 	 Loaded
# audio_branch.layers.2.blocks.1.attn.proj.bias 	 Loaded
# audio_branch.layers.2.blocks.1.norm2.weight 	 Loaded
# audio_branch.layers.2.blocks.1.norm2.bias 	 Loaded
# audio_branch.layers.2.blocks.1.mlp.fc1.weight 	 Loaded
# audio_branch.layers.2.blocks.1.mlp.fc1.bias 	 Loaded
# audio_branch.layers.2.blocks.1.mlp.fc2.weight 	 Loaded
# audio_branch.layers.2.blocks.1.mlp.fc2.bias 	 Loaded
# audio_branch.layers.2.blocks.2.norm1.weight 	 Loaded
# audio_branch.layers.2.blocks.2.norm1.bias 	 Loaded
# audio_branch.layers.2.blocks.2.attn.relative_position_bias_table 	 Loaded
# audio_branch.layers.2.blocks.2.attn.qkv.weight 	 Loaded
# audio_branch.layers.2.blocks.2.attn.qkv.bias 	 Loaded
# audio_branch.layers.2.blocks.2.attn.proj.weight 	 Loaded
# audio_branch.layers.2.blocks.2.attn.proj.bias 	 Loaded
# audio_branch.layers.2.blocks.2.norm2.weight 	 Loaded
# audio_branch.layers.2.blocks.2.norm2.bias 	 Loaded
# audio_branch.layers.2.blocks.2.mlp.fc1.weight 	 Loaded
# audio_branch.layers.2.blocks.2.mlp.fc1.bias 	 Loaded
# audio_branch.layers.2.blocks.2.mlp.fc2.weight 	 Loaded
# audio_branch.layers.2.blocks.2.mlp.fc2.bias 	 Loaded
# audio_branch.layers.2.blocks.3.norm1.weight 	 Loaded
# audio_branch.layers.2.blocks.3.norm1.bias 	 Loaded
# audio_branch.layers.2.blocks.3.attn.relative_position_bias_table 	 Loaded
# audio_branch.layers.2.blocks.3.attn.qkv.weight 	 Loaded
# audio_branch.layers.2.blocks.3.attn.qkv.bias 	 Loaded
# audio_branch.layers.2.blocks.3.attn.proj.weight 	 Loaded
# audio_branch.layers.2.blocks.3.attn.proj.bias 	 Loaded
# audio_branch.layers.2.blocks.3.norm2.weight 	 Loaded
# audio_branch.layers.2.blocks.3.norm2.bias 	 Loaded
# audio_branch.layers.2.blocks.3.mlp.fc1.weight 	 Loaded
# audio_branch.layers.2.blocks.3.mlp.fc1.bias 	 Loaded
# audio_branch.layers.2.blocks.3.mlp.fc2.weight 	 Loaded
# audio_branch.layers.2.blocks.3.mlp.fc2.bias 	 Loaded
# audio_branch.layers.2.blocks.4.norm1.weight 	 Loaded
# audio_branch.layers.2.blocks.4.norm1.bias 	 Loaded
# audio_branch.layers.2.blocks.4.attn.relative_position_bias_table 	 Loaded
# audio_branch.layers.2.blocks.4.attn.qkv.weight 	 Loaded
# audio_branch.layers.2.blocks.4.attn.qkv.bias 	 Loaded
# audio_branch.layers.2.blocks.4.attn.proj.weight 	 Loaded
# audio_branch.layers.2.blocks.4.attn.proj.bias 	 Loaded
# audio_branch.layers.2.blocks.4.norm2.weight 	 Loaded
# audio_branch.layers.2.blocks.4.norm2.bias 	 Loaded
# audio_branch.layers.2.blocks.4.mlp.fc1.weight 	 Loaded
# audio_branch.layers.2.blocks.4.mlp.fc1.bias 	 Loaded
# audio_branch.layers.2.blocks.4.mlp.fc2.weight 	 Loaded
# audio_branch.layers.2.blocks.4.mlp.fc2.bias 	 Loaded
# audio_branch.layers.2.blocks.5.norm1.weight 	 Loaded
# audio_branch.layers.2.blocks.5.norm1.bias 	 Loaded
# audio_branch.layers.2.blocks.5.attn.relative_position_bias_table 	 Loaded
# audio_branch.layers.2.blocks.5.attn.qkv.weight 	 Loaded
# audio_branch.layers.2.blocks.5.attn.qkv.bias 	 Loaded
# audio_branch.layers.2.blocks.5.attn.proj.weight 	 Loaded
# audio_branch.layers.2.blocks.5.attn.proj.bias 	 Loaded
# audio_branch.layers.2.blocks.5.norm2.weight 	 Loaded
# audio_branch.layers.2.blocks.5.norm2.bias 	 Loaded
# audio_branch.layers.2.blocks.5.mlp.fc1.weight 	 Loaded
# audio_branch.layers.2.blocks.5.mlp.fc1.bias 	 Loaded
# audio_branch.layers.2.blocks.5.mlp.fc2.weight 	 Loaded
# audio_branch.layers.2.blocks.5.mlp.fc2.bias 	 Loaded
# audio_branch.layers.2.downsample.reduction.weight 	 Loaded
# audio_branch.layers.2.downsample.norm.weight 	 Loaded
# audio_branch.layers.2.downsample.norm.bias 	 Loaded
# audio_branch.layers.3.blocks.0.norm1.weight 	 Loaded
# audio_branch.layers.3.blocks.0.norm1.bias 	 Loaded
# audio_branch.layers.3.blocks.0.attn.relative_position_bias_table 	 Loaded
# audio_branch.layers.3.blocks.0.attn.qkv.weight 	 Loaded
# audio_branch.layers.3.blocks.0.attn.qkv.bias 	 Loaded
# audio_branch.layers.3.blocks.0.attn.proj.weight 	 Loaded
# audio_branch.layers.3.blocks.0.attn.proj.bias 	 Loaded
# audio_branch.layers.3.blocks.0.norm2.weight 	 Loaded
# audio_branch.layers.3.blocks.0.norm2.bias 	 Loaded
# audio_branch.layers.3.blocks.0.mlp.fc1.weight 	 Loaded
# audio_branch.layers.3.blocks.0.mlp.fc1.bias 	 Loaded
# audio_branch.layers.3.blocks.0.mlp.fc2.weight 	 Loaded
# audio_branch.layers.3.blocks.0.mlp.fc2.bias 	 Loaded
# audio_branch.layers.3.blocks.1.norm1.weight 	 Loaded
# audio_branch.layers.3.blocks.1.norm1.bias 	 Loaded
# audio_branch.layers.3.blocks.1.attn.relative_position_bias_table 	 Loaded
# audio_branch.layers.3.blocks.1.attn.qkv.weight 	 Loaded
# audio_branch.layers.3.blocks.1.attn.qkv.bias 	 Loaded
# audio_branch.layers.3.blocks.1.attn.proj.weight 	 Loaded
# audio_branch.layers.3.blocks.1.attn.proj.bias 	 Loaded
# audio_branch.layers.3.blocks.1.norm2.weight 	 Loaded
# audio_branch.layers.3.blocks.1.norm2.bias 	 Loaded
# audio_branch.layers.3.blocks.1.mlp.fc1.weight 	 Loaded
# audio_branch.layers.3.blocks.1.mlp.fc1.bias 	 Loaded
# audio_branch.layers.3.blocks.1.mlp.fc2.weight 	 Loaded
# audio_branch.layers.3.blocks.1.mlp.fc2.bias 	 Loaded
# audio_branch.norm.weight 	 Loaded
# audio_branch.norm.bias 	 Loaded
# audio_branch.tscam_conv.weight 	 Loaded
# audio_branch.tscam_conv.bias 	 Loaded
# audio_branch.head.weight 	 Loaded
# audio_branch.head.bias 	 Loaded
# text_branch.embeddings.word_embeddings.weight 	 Loaded
# text_branch.embeddings.position_embeddings.weight 	 Loaded
# text_branch.embeddings.token_type_embeddings.weight 	 Loaded
# text_branch.embeddings.LayerNorm.weight 	 Loaded
# text_branch.embeddings.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.0.attention.self.query.weight 	 Loaded
# text_branch.encoder.layer.0.attention.self.query.bias 	 Loaded
# text_branch.encoder.layer.0.attention.self.key.weight 	 Loaded
# text_branch.encoder.layer.0.attention.self.key.bias 	 Loaded
# text_branch.encoder.layer.0.attention.self.value.weight 	 Loaded
# text_branch.encoder.layer.0.attention.self.value.bias 	 Loaded
# text_branch.encoder.layer.0.attention.output.dense.weight 	 Loaded
# text_branch.encoder.layer.0.attention.output.dense.bias 	 Loaded
# text_branch.encoder.layer.0.attention.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.0.attention.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.0.intermediate.dense.weight 	 Loaded
# text_branch.encoder.layer.0.intermediate.dense.bias 	 Loaded
# text_branch.encoder.layer.0.output.dense.weight 	 Loaded
# text_branch.encoder.layer.0.output.dense.bias 	 Loaded
# text_branch.encoder.layer.0.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.0.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.1.attention.self.query.weight 	 Loaded
# text_branch.encoder.layer.1.attention.self.query.bias 	 Loaded
# text_branch.encoder.layer.1.attention.self.key.weight 	 Loaded
# text_branch.encoder.layer.1.attention.self.key.bias 	 Loaded
# text_branch.encoder.layer.1.attention.self.value.weight 	 Loaded
# text_branch.encoder.layer.1.attention.self.value.bias 	 Loaded
# text_branch.encoder.layer.1.attention.output.dense.weight 	 Loaded
# text_branch.encoder.layer.1.attention.output.dense.bias 	 Loaded
# text_branch.encoder.layer.1.attention.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.1.attention.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.1.intermediate.dense.weight 	 Loaded
# text_branch.encoder.layer.1.intermediate.dense.bias 	 Loaded
# text_branch.encoder.layer.1.output.dense.weight 	 Loaded
# text_branch.encoder.layer.1.output.dense.bias 	 Loaded
# text_branch.encoder.layer.1.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.1.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.2.attention.self.query.weight 	 Loaded
# text_branch.encoder.layer.2.attention.self.query.bias 	 Loaded
# text_branch.encoder.layer.2.attention.self.key.weight 	 Loaded
# text_branch.encoder.layer.2.attention.self.key.bias 	 Loaded
# text_branch.encoder.layer.2.attention.self.value.weight 	 Loaded
# text_branch.encoder.layer.2.attention.self.value.bias 	 Loaded
# text_branch.encoder.layer.2.attention.output.dense.weight 	 Loaded
# text_branch.encoder.layer.2.attention.output.dense.bias 	 Loaded
# text_branch.encoder.layer.2.attention.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.2.attention.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.2.intermediate.dense.weight 	 Loaded
# text_branch.encoder.layer.2.intermediate.dense.bias 	 Loaded
# text_branch.encoder.layer.2.output.dense.weight 	 Loaded
# text_branch.encoder.layer.2.output.dense.bias 	 Loaded
# text_branch.encoder.layer.2.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.2.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.3.attention.self.query.weight 	 Loaded
# text_branch.encoder.layer.3.attention.self.query.bias 	 Loaded
# text_branch.encoder.layer.3.attention.self.key.weight 	 Loaded
# text_branch.encoder.layer.3.attention.self.key.bias 	 Loaded
# text_branch.encoder.layer.3.attention.self.value.weight 	 Loaded
# text_branch.encoder.layer.3.attention.self.value.bias 	 Loaded
# text_branch.encoder.layer.3.attention.output.dense.weight 	 Loaded
# text_branch.encoder.layer.3.attention.output.dense.bias 	 Loaded
# text_branch.encoder.layer.3.attention.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.3.attention.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.3.intermediate.dense.weight 	 Loaded
# text_branch.encoder.layer.3.intermediate.dense.bias 	 Loaded
# text_branch.encoder.layer.3.output.dense.weight 	 Loaded
# text_branch.encoder.layer.3.output.dense.bias 	 Loaded
# text_branch.encoder.layer.3.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.3.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.4.attention.self.query.weight 	 Loaded
# text_branch.encoder.layer.4.attention.self.query.bias 	 Loaded
# text_branch.encoder.layer.4.attention.self.key.weight 	 Loaded
# text_branch.encoder.layer.4.attention.self.key.bias 	 Loaded
# text_branch.encoder.layer.4.attention.self.value.weight 	 Loaded
# text_branch.encoder.layer.4.attention.self.value.bias 	 Loaded
# text_branch.encoder.layer.4.attention.output.dense.weight 	 Loaded
# text_branch.encoder.layer.4.attention.output.dense.bias 	 Loaded
# text_branch.encoder.layer.4.attention.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.4.attention.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.4.intermediate.dense.weight 	 Loaded
# text_branch.encoder.layer.4.intermediate.dense.bias 	 Loaded
# text_branch.encoder.layer.4.output.dense.weight 	 Loaded
# text_branch.encoder.layer.4.output.dense.bias 	 Loaded
# text_branch.encoder.layer.4.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.4.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.5.attention.self.query.weight 	 Loaded
# text_branch.encoder.layer.5.attention.self.query.bias 	 Loaded
# text_branch.encoder.layer.5.attention.self.key.weight 	 Loaded
# text_branch.encoder.layer.5.attention.self.key.bias 	 Loaded
# text_branch.encoder.layer.5.attention.self.value.weight 	 Loaded
# text_branch.encoder.layer.5.attention.self.value.bias 	 Loaded
# text_branch.encoder.layer.5.attention.output.dense.weight 	 Loaded
# text_branch.encoder.layer.5.attention.output.dense.bias 	 Loaded
# text_branch.encoder.layer.5.attention.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.5.attention.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.5.intermediate.dense.weight 	 Loaded
# text_branch.encoder.layer.5.intermediate.dense.bias 	 Loaded
# text_branch.encoder.layer.5.output.dense.weight 	 Loaded
# text_branch.encoder.layer.5.output.dense.bias 	 Loaded
# text_branch.encoder.layer.5.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.5.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.6.attention.self.query.weight 	 Loaded
# text_branch.encoder.layer.6.attention.self.query.bias 	 Loaded
# text_branch.encoder.layer.6.attention.self.key.weight 	 Loaded
# text_branch.encoder.layer.6.attention.self.key.bias 	 Loaded
# text_branch.encoder.layer.6.attention.self.value.weight 	 Loaded
# text_branch.encoder.layer.6.attention.self.value.bias 	 Loaded
# text_branch.encoder.layer.6.attention.output.dense.weight 	 Loaded
# text_branch.encoder.layer.6.attention.output.dense.bias 	 Loaded
# text_branch.encoder.layer.6.attention.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.6.attention.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.6.intermediate.dense.weight 	 Loaded
# text_branch.encoder.layer.6.intermediate.dense.bias 	 Loaded
# text_branch.encoder.layer.6.output.dense.weight 	 Loaded
# text_branch.encoder.layer.6.output.dense.bias 	 Loaded
# text_branch.encoder.layer.6.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.6.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.7.attention.self.query.weight 	 Loaded
# text_branch.encoder.layer.7.attention.self.query.bias 	 Loaded
# text_branch.encoder.layer.7.attention.self.key.weight 	 Loaded
# text_branch.encoder.layer.7.attention.self.key.bias 	 Loaded
# text_branch.encoder.layer.7.attention.self.value.weight 	 Loaded
# text_branch.encoder.layer.7.attention.self.value.bias 	 Loaded
# text_branch.encoder.layer.7.attention.output.dense.weight 	 Loaded
# text_branch.encoder.layer.7.attention.output.dense.bias 	 Loaded
# text_branch.encoder.layer.7.attention.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.7.attention.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.7.intermediate.dense.weight 	 Loaded
# text_branch.encoder.layer.7.intermediate.dense.bias 	 Loaded
# text_branch.encoder.layer.7.output.dense.weight 	 Loaded
# text_branch.encoder.layer.7.output.dense.bias 	 Loaded
# text_branch.encoder.layer.7.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.7.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.8.attention.self.query.weight 	 Loaded
# text_branch.encoder.layer.8.attention.self.query.bias 	 Loaded
# text_branch.encoder.layer.8.attention.self.key.weight 	 Loaded
# text_branch.encoder.layer.8.attention.self.key.bias 	 Loaded
# text_branch.encoder.layer.8.attention.self.value.weight 	 Loaded
# text_branch.encoder.layer.8.attention.self.value.bias 	 Loaded
# text_branch.encoder.layer.8.attention.output.dense.weight 	 Loaded
# text_branch.encoder.layer.8.attention.output.dense.bias 	 Loaded
# text_branch.encoder.layer.8.attention.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.8.attention.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.8.intermediate.dense.weight 	 Loaded
# text_branch.encoder.layer.8.intermediate.dense.bias 	 Loaded
# text_branch.encoder.layer.8.output.dense.weight 	 Loaded
# text_branch.encoder.layer.8.output.dense.bias 	 Loaded
# text_branch.encoder.layer.8.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.8.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.9.attention.self.query.weight 	 Loaded
# text_branch.encoder.layer.9.attention.self.query.bias 	 Loaded
# text_branch.encoder.layer.9.attention.self.key.weight 	 Loaded
# text_branch.encoder.layer.9.attention.self.key.bias 	 Loaded
# text_branch.encoder.layer.9.attention.self.value.weight 	 Loaded
# text_branch.encoder.layer.9.attention.self.value.bias 	 Loaded
# text_branch.encoder.layer.9.attention.output.dense.weight 	 Loaded
# text_branch.encoder.layer.9.attention.output.dense.bias 	 Loaded
# text_branch.encoder.layer.9.attention.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.9.attention.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.9.intermediate.dense.weight 	 Loaded
# text_branch.encoder.layer.9.intermediate.dense.bias 	 Loaded
# text_branch.encoder.layer.9.output.dense.weight 	 Loaded
# text_branch.encoder.layer.9.output.dense.bias 	 Loaded
# text_branch.encoder.layer.9.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.9.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.10.attention.self.query.weight 	 Loaded
# text_branch.encoder.layer.10.attention.self.query.bias 	 Loaded
# text_branch.encoder.layer.10.attention.self.key.weight 	 Loaded
# text_branch.encoder.layer.10.attention.self.key.bias 	 Loaded
# text_branch.encoder.layer.10.attention.self.value.weight 	 Loaded
# text_branch.encoder.layer.10.attention.self.value.bias 	 Loaded
# text_branch.encoder.layer.10.attention.output.dense.weight 	 Loaded
# text_branch.encoder.layer.10.attention.output.dense.bias 	 Loaded
# text_branch.encoder.layer.10.attention.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.10.attention.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.10.intermediate.dense.weight 	 Loaded
# text_branch.encoder.layer.10.intermediate.dense.bias 	 Loaded
# text_branch.encoder.layer.10.output.dense.weight 	 Loaded
# text_branch.encoder.layer.10.output.dense.bias 	 Loaded
# text_branch.encoder.layer.10.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.10.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.11.attention.self.query.weight 	 Loaded
# text_branch.encoder.layer.11.attention.self.query.bias 	 Loaded
# text_branch.encoder.layer.11.attention.self.key.weight 	 Loaded
# text_branch.encoder.layer.11.attention.self.key.bias 	 Loaded
# text_branch.encoder.layer.11.attention.self.value.weight 	 Loaded
# text_branch.encoder.layer.11.attention.self.value.bias 	 Loaded
# text_branch.encoder.layer.11.attention.output.dense.weight 	 Loaded
# text_branch.encoder.layer.11.attention.output.dense.bias 	 Loaded
# text_branch.encoder.layer.11.attention.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.11.attention.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.11.intermediate.dense.weight 	 Loaded
# text_branch.encoder.layer.11.intermediate.dense.bias 	 Loaded
# text_branch.encoder.layer.11.output.dense.weight 	 Loaded
# text_branch.encoder.layer.11.output.dense.bias 	 Loaded
# text_branch.encoder.layer.11.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.11.output.LayerNorm.bias 	 Loaded
# text_branch.pooler.dense.weight 	 Loaded
# text_branch.pooler.dense.bias 	 Loaded
# text_transform.sequential.0.weight 	 Loaded
# text_transform.sequential.0.bias 	 Loaded
# text_transform.sequential.3.weight 	 Loaded
# text_transform.sequential.3.bias 	 Loaded
# text_projection.0.weight 	 Loaded
# text_projection.0.bias 	 Loaded
# text_projection.2.weight 	 Loaded
# text_projection.2.bias 	 Loaded
# audio_transform.sequential.0.weight 	 Loaded
# audio_transform.sequential.0.bias 	 Loaded
# audio_transform.sequential.3.weight 	 Loaded
# audio_transform.sequential.3.bias 	 Loaded
# audio_projection.0.weight 	 Loaded
# audio_projection.0.bias 	 Loaded
# audio_projection.2.weight 	 Loaded
# audio_projection.2.bias 	 Loaded

# %%
CSV_PATH = "/content/drive/MyDrive/graduateproject/data/songs_out_final.csv"
MP3_DIR = "/content/drive/MyDrive/graduateproject/data/song_mp3"
TOP_K = 4  # 곡당 추출할 상위 가사 줄 개수

# %%
GENRE_TAGS: List[str] = [
    "Hip-Hop", "Rap", "Rock", "Alternative Rock", "Punk",
    "Pop", "Indie Pop", "R&B", "Soul", "Jazz", "Classical",
    "Electronic", "Ambient", "Folk", "Acoustic",
    "Reggae", "Latin", "Country", "Blues", "Experimental"
]

MOOD_TAGS: List[str] = [
    "Happy", "Sad", "Energetic", "Chill", "Relaxed", "Dark", "Romantic",
    "Uplifting", "Melancholic", "Angry", "Nostalgic", "Dreamy",
    "Hypnotic", "Mysterious", "Playful", "Aggressive"
]

TEXTURE_TAGS: List[str] = [
    "Lo-fi", "Clean", "Distorted", "Warm", "Bright", "Harsh", "Smooth",
    "Gritty", "Metallic", "Acoustic", "Synthetic", "Dry", "Wet",
    "Punchy", "Muffled"
]

ALL_TAGS: List[str] = GENRE_TAGS + MOOD_TAGS + TEXTURE_TAGS

# 태그 → 카테고리 매핑
TAG_CATEGORY_MAP: Dict[str, str] = {}
for t in GENRE_TAGS:
    TAG_CATEGORY_MAP[t] = "genre"
for t in MOOD_TAGS:
    TAG_CATEGORY_MAP[t] = "mood"
for t in TEXTURE_TAGS:
    TAG_CATEGORY_MAP[t] = "texture"

# 텍스트 임베딩 (문장 프롬프트를 통해 정확도 향상)
TAG_PROMPTS: List[str] = [f"A {t} music" for t in ALL_TAGS]
TEXT_EMBEDDINGS: torch.Tensor = clap_model.get_text_embedding(TAG_PROMPTS, use_tensor=True)

# 카테고리 인덱스 (ALL_TAGS에서의 위치)
GENRE_IDX: List[int] = [ALL_TAGS.index(t) for t in GENRE_TAGS]
MOOD_IDX: List[int] = [ALL_TAGS.index(t) for t in MOOD_TAGS]
TEXTURE_IDX: List[int] = [ALL_TAGS.index(t) for t in TEXTURE_TAGS]

# %%
def get_audio_embedding_from_path(path: str) -> torch.Tensor:
    # Load and resample audio
    audio_data, _ = librosa.load(path, sr=48000)
    audio_data = audio_data.reshape(1, -1)  # [1, T]

    # 양자화 (quantization)
    def int16_to_float32(x: np.ndarray) -> np.ndarray:
        return (x / 32767.0).astype(np.float32)

    def float32_to_int16(x: np.ndarray) -> np.ndarray:
        x = np.clip(x, a_min=-1., a_max=1.)
        return (x * 32767.).astype(np.int16)

    audio_data = torch.from_numpy(int16_to_float32(float32_to_int16(audio_data))).float()
    return clap_model.get_audio_embedding_from_data(x=audio_data, use_tensor=True)

# %%
def get_top_k_tags_by_category(audio_embedding: torch.Tensor, top_k: int = 4) -> Dict[str, List[str]]:
    """오디오 임베딩과 사전 계산된 TEXT_EMBEDDINGS의 코사인 유사도로
    장르/무드/텍스처 카테고리별 상위 top_k 태그를 반환합니다.

    Returns: { "genre": [...], "mood": [...], "texture": [...] }
    """
    sims = F.cosine_similarity(audio_embedding, TEXT_EMBEDDINGS)  # [N_tags]

    # 카테고리별 (tag, score) 수집
    scores_by_cat: Dict[str, List[Tuple[str, float]]] = {"genre": [], "mood": [], "texture": []}
    for idx, score in enumerate(sims):
        tag = ALL_TAGS[idx]
        cat = TAG_CATEGORY_MAP.get(tag, "")
        if cat in scores_by_cat:
            scores_by_cat[cat].append((tag, float(score.item())))

    # 각 카테고리 상위 top_k 추출
    top_by_cat: Dict[str, List[str]] = {}
    for cat, pairs in scores_by_cat.items():
        pairs.sort(key=lambda x: x[1], reverse=True)
        top_by_cat[cat] = [t for t, _ in pairs[:max(0, top_k)]]
    return top_by_cat


def compute_category_tags_for_audio_path(audio_path: str, top_k_per_category: int = 4) -> Tuple[List[str], List[str], List[str]]:
    """오디오 파일 경로에서 카테고리별 태그(장르/무드/텍스처)를 계산합니다."""
    audio_emb = get_audio_embedding_from_path(audio_path)
    top_dict = get_top_k_tags_by_category(audio_emb, top_k=top_k_per_category)
    return top_dict.get("genre", []), top_dict.get("mood", []), top_dict.get("texture", [])


def get_category_score_vectors(audio_embedding: torch.Tensor) -> Tuple[List[float], List[float], List[float]]:
    """카테고리별 유사도 벡터를 반환합니다. 각 벡터의 차원은 해당 태그 배열 크기와 동일합니다.

    Returns:
        (genre_scores, mood_scores, texture_scores)
    """
    sims = F.cosine_similarity(audio_embedding, TEXT_EMBEDDINGS)  # [N_tags]
    genre_scores = [float(sims[i].item()) for i in GENRE_IDX]
    mood_scores = [float(sims[i].item()) for i in MOOD_IDX]
    texture_scores = [float(sims[i].item()) for i in TEXTURE_IDX]
    return genre_scores, mood_scores, texture_scores


def write_category_tags_to_csv(
    csv_path: str,
    mp3_dir: str,
    genre_col: str = "genre_tags",
    mood_col: str = "mood_tags",
    texture_col: str = "texture_tags",
    genre_vec_col: str = "genre_vector",
    mood_vec_col: str = "mood_vector",
    texture_vec_col: str = "texture_vector",
    delimiter: str = " | ",
    top_k_per_category: int = 4,
    store_vectors: bool = True,
) -> None:
    """MP3 디렉터리의 파일 순서와 CSV 데이터 행 순서를 맞춰
    각 곡의 장르/무드/텍스처 태그를 계산하여 CSV에 열로 기록합니다.
    열이 없으면 생성합니다.
    """
    if not os.path.exists(csv_path):
        print(f"[WARN] CSV가 없습니다: {csv_path}")
        return
    mp3_files = list_mp3_files_sorted(mp3_dir)

    # CSV 전체 로드
    with open(csv_path, "r", encoding="utf-8-sig", newline="") as f:
        reader = csv.reader(f)
        rows = list(reader)
    if not rows:
        print("[WARN] 빈 CSV")
        return

    header = rows[0]
    data_rows = rows[1:]

    # 열 인덱스 확보 또는 생성
    lower = [c.lower() if isinstance(c, str) else c for c in header]
    def ensure_col(col_name: str) -> int:
        try:
            return lower.index(col_name.lower())
        except ValueError:
            header.append(col_name)
            lower.append(col_name.lower())
            for r in data_rows:
                r.extend([""])
            return len(header) - 1

    genre_idx = ensure_col(genre_col)
    mood_idx = ensure_col(mood_col)
    texture_idx = ensure_col(texture_col)
    if store_vectors:
        genre_vec_idx = ensure_col(genre_vec_col)
        mood_vec_idx = ensure_col(mood_vec_col)
        texture_vec_idx = ensure_col(texture_vec_col)

    n = min(len(mp3_files), len(data_rows))
    if n == 0:
        print("[WARN] 처리할 MP3 또는 데이터 행이 없습니다.")
        return

    for i in range(n):
        mp3_path = mp3_files[i]
        try:
            g_tags, m_tags, t_tags = compute_category_tags_for_audio_path(mp3_path, top_k_per_category)
            if store_vectors:
                audio_emb = get_audio_embedding_from_path(mp3_path)
                g_vec, m_vec, t_vec = get_category_score_vectors(audio_emb)
        except Exception as e:
            print(f"[SKIP] #{i+1}: {os.path.basename(mp3_path)} 오류: {e}")
            g_tags, m_tags, t_tags = [], [], []
            if store_vectors:
                g_vec, m_vec, t_vec = [], [], []

        row = data_rows[i]
        # row 길이가 부족할 수 있으니 보정
        max_base = max(genre_idx, mood_idx, texture_idx)
        if store_vectors:
            max_base = max(max_base, genre_vec_idx, mood_vec_idx, texture_vec_idx)
        if max_base >= len(row):
            row.extend([""] * (max_base - len(row) + 1))
        row[genre_idx] = delimiter.join(g_tags)
        row[mood_idx] = delimiter.join(m_tags)
        row[texture_idx] = delimiter.join(t_tags)
        if store_vectors:
            row[genre_vec_idx] = json.dumps(g_vec, ensure_ascii=False)
            row[mood_vec_idx] = json.dumps(m_vec, ensure_ascii=False)
            row[texture_vec_idx] = json.dumps(t_vec, ensure_ascii=False)
        print(f"[TAGS] #{i+1}: {os.path.basename(mp3_path)} → G:{len(g_tags)} M:{len(m_tags)} T:{len(t_tags)}" + (" + vectors" if store_vectors else ""))

    # 저장
    with open(csv_path, "w", encoding="utf-8-sig", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(header)
        writer.writerows(data_rows)
    print(f"[WRITE] 태그 열 업데이트 완료 → {csv_path}")


def natural_key(s: str) -> List:
    # 숫자를 자연스럽게 정렬하기 위한 키
    return [int(text) if text.isdigit() else text.lower() for text in re.split(r"(\d+)", s)]


def list_mp3_files_sorted(mp3_dir: str) -> List[str]:
    if not os.path.isdir(mp3_dir):
        return []
    files = [os.path.join(mp3_dir, f) for f in os.listdir(mp3_dir) if f.lower().endswith(".mp3")]
    files.sort(key=lambda p: natural_key(os.path.basename(p)))
    return files


def read_lyrics_from_csv(csv_path: str) -> List[str]:
    lyrics_list: List[str] = []
    if not os.path.exists(csv_path):
        return lyrics_list
    with open(csv_path, "r", encoding="utf-8-sig", newline="") as f:
        reader = csv.reader(f)
        first = next(reader, None)
        if first is None:
            return lyrics_list

        # 헤더 여부 판별 및 가사 열 인덱스 탐색
        header_candidates = ["lyrics", "lyric", "가사", "text", "content"]
        has_header = any(isinstance(x, str) and x.strip() for x in first)
        lyric_col_idx: Optional[int] = None

        # 헤더로 판단되면 이름 기반 탐색
        if has_header and any(h.lower() in [c.lower() for c in first if isinstance(c, str)] for h in header_candidates):
            header = first
            lower = [c.lower() if isinstance(c, str) else c for c in header]
            for name in header_candidates:
                try:
                    j = lower.index(name.lower())
                    lyric_col_idx = j
                    break
                except ValueError:
                    continue
            rows_iter = reader
        else:
            # 헤더 없다고 보고 첫 행도 데이터로 포함, 가사는 마지막 열로 가정 시도
            lyric_col_idx = len(first) - 1 if len(first) > 0 else None
            rows_iter = [first] + list(reader)

        for row in rows_iter:
            if lyric_col_idx is None or lyric_col_idx >= len(row):
                lyrics_list.append("")
                continue
            val = row[lyric_col_idx]
            lyrics_list.append(val if isinstance(val, str) else str(val))
    return lyrics_list


def split_lyrics_to_lines(lyric_text: str) -> List[str]:
    return [line.strip() for line in (lyric_text or "").split("\n") if line and line.strip()]


def extract_top_lines_for_audio(lyric_text: str, audio_path: str, top_k: int = 10) -> List[str]:
    lines = split_lyrics_to_lines(lyric_text)
    if not lines:
        return []
    text_embs = clap_model.get_text_embedding(lines, use_tensor=True)  # [N, D]
    audio_emb = get_audio_embedding_from_path(audio_path)  # [1, D]
    sims = F.cosine_similarity(audio_emb, text_embs)  # [N]
    sorted_indices = torch.argsort(sims, descending=True)
    top_lines: List[str] = []
    seen: set = set()
    for idx in sorted_indices:
        line = lines[int(idx.item())]
        if line in seen:
            continue
        top_lines.append(line)
        seen.add(line)
        if len(top_lines) >= top_k:
            break
    return top_lines

def write_summary_to_csv(csv_path: str, tags_list: List[List[str]], summary_col_candidates: Optional[List[str]] = None, delimiter: str = " | ") -> None:
    """tags_list를 CSV의 summary(요약) 열에 씁니다. 열이 없으면 생성.

    - summary 열 후보명: 기본 ["summary", "summary_c(mood_out)", "summary_c", "요약"]
    - tags_list 길이는 CSV 데이터 행 수(헤더 제외) 이상이면 행 수만큼만 사용
    - 각 곡의 top 라인들을 delimiter로 연결해 기록
    """
    if summary_col_candidates is None:
        summary_col_candidates = ["summary", "summary_c(mood_out)", "summary_c", "요약"]

    if not os.path.exists(csv_path):
        print(f"[WARN] CSV가 없습니다: {csv_path}")
        return

    # CSV 전체 로드
    with open(csv_path, "r", encoding="utf-8-sig", newline="") as f:
        reader = csv.reader(f)
        rows = list(reader)
    if not rows:
        print("[WARN] 빈 CSV")
        return

    header = rows[0]
    data_rows = rows[1:]

    # summary 열 탐색 또는 생성
    lower = [c.lower() if isinstance(c, str) else c for c in header]
    summary_idx: Optional[int] = None
    for cand in summary_col_candidates:
        try:
            j = lower.index(cand.lower())
            summary_idx = j
            break
        except ValueError:
            continue
    if summary_idx is None:
        header.append(summary_col_candidates[0])
        summary_idx = len(header) - 1
        for r in data_rows:
            r.extend([""])

    # 데이터 행에 tags_list 반영
    limit = min(len(data_rows), len(tags_list))
    for i in range(limit):
        summary_text = delimiter.join(tags_list[i]) if tags_list[i] else ""
        row = data_rows[i]
        # row 길이가 부족할 수 있으니 보정
        if summary_idx >= len(row):
            row.extend([""] * (summary_idx - len(row) + 1))
        row[summary_idx] = summary_text

    # 다시 저장
    with open(csv_path, "w", encoding="utf-8-sig", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(header)
        writer.writerows(data_rows)
    print(f"[WRITE] 요약 열 업데이트 완료 → {csv_path}")

# %%
def _find_col_idx(header: List[str], candidates: List[str]) -> Optional[int]:
    lower = [c.lower() if isinstance(c, str) else c for c in header]
    for cand in candidates:
        try:
            return lower.index(cand.lower())
        except ValueError:
            continue
    return None

# %%
def _find_col_indices(header: List[str], candidates: List[str]) -> List[int]:
    """Return indices for all columns whose names match any in candidates (case-insensitive)."""
    lower = [c.lower() if isinstance(c, str) else c for c in header]
    wanted = {c.lower() for c in candidates}
    indices: List[int] = []
    for i, name in enumerate(lower):
        if isinstance(name, str) and name in wanted:
            indices.append(i)
    return indices

# %%
def _parse_json_vector(cell: str) -> Optional[List[float]]:
    if not isinstance(cell, str) or not cell.strip():
        return None
    try:
        v = json.loads(cell)
        if isinstance(v, list) and all(isinstance(x, (int, float)) for x in v):
            return [float(x) for x in v]
    except Exception:
        return None
    return None


def _resolve_seed_to_index(seed: object, titles: List[str]) -> Optional[int]:
    # Numeric index support (both 0-based and 1-based attempts)
    try:
        idx = int(seed)
        if 0 <= idx < len(titles):
            return idx
        if 1 <= idx <= len(titles):
            return idx - 1
    except Exception:
        pass
    # Title matching (case-insensitive, stripped)
    if isinstance(seed, str):
        target = seed.strip().lower()
        for i, t in enumerate(titles):
            if isinstance(t, str) and t.strip().lower() == target:
                return i
    return None

def recommend_by_knn(
    csv_path: str,
    seeds: List[object],
    k_neighbors: int = 3,
    per_seed_top: int = 3,
    final_top: int = 3,
    vector_col: str = "genre_vector",
    label_col_candidates: Optional[List[str]] = None,
    title_col_candidates: Optional[List[str]] = None,
) -> Dict[str, object]:
    """
    - 입력 seeds: 곡 제목(문자열) 또는 번호(정수/문자열 숫자) 3개
    - 각 seed마다 genre_vector 기반 코사인 유사도 Top-k 이웃을 찾고,
      이웃들의 라벨(예: 옷 스타일) 분포에서 상위 per_seed_top을 뽑음
    - 3개의 seed 결과(최대 9개 라벨)을 다시 통계내어 상위 final_top을 반환

    Returns dict with keys:
      "per_seed_top_labels": List[List[str]]
      "final_top_labels": List[str]
      "neighbors_indices": List[List[int]]  # per seed neighbor row indices
    """
    if label_col_candidates is None:
        # 기본적으로 CSV의 스타일 열 3종을 우선 사용
        label_col_candidates = [
            "style_first", "style_second", "style_third",
            "outfit_style", "style", "clothes_style", "cloth_style",
            "패션", "스타일", "outfit"
        ]
    if title_col_candidates is None:
        title_col_candidates = ["title", "song", "name", "track", "곡명", "제목"]

    # Load CSV
    if not os.path.exists(csv_path):
        raise FileNotFoundError(csv_path)
    with open(csv_path, "r", encoding="utf-8-sig", newline="") as f:
        reader = csv.reader(f)
        rows = list(reader)
    if not rows:
        raise ValueError("빈 CSV")

    header = rows[0]
    data_rows = rows[1:]
    if not data_rows:
        raise ValueError("데이터 행이 없습니다")

    vec_idx = _find_col_idx(header, [vector_col])
    if vec_idx is None:
        raise ValueError(f"벡터 열을 찾을 수 없습니다: {vector_col}")

    title_idx = _find_col_idx(header, title_col_candidates)
    titles = [r[title_idx] if (title_idx is not None and title_idx < len(r)) else str(i) for i, r in enumerate(data_rows)]

    # 다중 라벨 열 지원 (예: style_first/second/third)
    label_indices = _find_col_indices(header, label_col_candidates)
    # 장르 태그 열 (옵션)
    genre_idx_opt = _find_col_idx(header, ["genre_tags"])  # 없을 수 있음

    # Build matrix of vectors
    vectors: List[Optional[List[float]]] = []
    for r in data_rows:
        cell = r[vec_idx] if vec_idx < len(r) else ""
        vectors.append(_parse_json_vector(cell))
    # Determine dimension
    dim = 0
    for v in vectors:
        if isinstance(v, list) and len(v) > 0:
            dim = len(v)
            break
    if dim == 0:
        raise ValueError("유효한 벡터가 없습니다")

    import numpy as _np
    M = _np.zeros((len(vectors), dim), dtype=_np.float32)
    valid = _np.zeros((len(vectors),), dtype=_np.bool_)
    for i, v in enumerate(vectors):
        if isinstance(v, list) and len(v) == dim:
            M[i, :] = _np.array(v, dtype=_np.float32)
            valid[i] = True

    def _cosine_sim_matrix_row(mat: _np.ndarray, idx: int) -> _np.ndarray:
        q = mat[idx]
        q_norm = _np.linalg.norm(q)
        if q_norm == 0:
            return _np.full((mat.shape[0],), -_np.inf, dtype=_np.float32)
        dot = mat @ q
        mat_norms = _np.linalg.norm(mat, axis=1)
        denom = (mat_norms * q_norm)
        with _np.errstate(divide='ignore', invalid='ignore'):
            sims = _np.where(denom > 0, dot / denom, -_np.inf)
        return sims

    # Resolve seeds → indices
    if len(seeds) != 3:
        raise ValueError("seeds는 3개여야 합니다")
    seed_indices: List[int] = []
    for s in seeds:
        idx = _resolve_seed_to_index(s, titles)
        if idx is None:
            raise ValueError(f"seed를 찾을 수 없습니다: {s}")
        seed_indices.append(idx)
    seed_titles: List[str] = [titles[i] for i in seed_indices]

    per_seed_neighbors: List[List[int]] = []
    per_seed_neighbor_titles: List[List[str]] = []
    per_seed_top_labels: List[List[str]] = []
    per_seed_top_genres: List[List[str]] = []
    global_counts: Dict[str, int] = {}
    global_genre_counts: Dict[str, int] = {}

    for si in seed_indices:
        if not valid[si]:
            per_seed_neighbors.append([])
            per_seed_top_labels.append([])
            continue
        sims = _cosine_sim_matrix_row(M, si)
        sims[si] = -_np.inf  # exclude self
        # sort indices by sims desc
        nn_idx = _np.argsort(-sims)
        # keep only valid rows
        nn_idx = [int(i) for i in nn_idx if valid[int(i)]]
        nn_idx = nn_idx[:max(0, k_neighbors)]
        per_seed_neighbors.append(nn_idx)
        per_seed_neighbor_titles.append([titles[ni] for ni in nn_idx])

        # Aggregate labels among neighbors (from multiple label columns if present)
        counts: Dict[str, int] = {}
        genre_counts: Dict[str, int] = {}
        for ni in nn_idx:
            if not label_indices:
                pass
            row = data_rows[ni]
            for li in label_indices:
                if li >= len(row):
                    continue
                cell = row[li]
                if not isinstance(cell, str) or not cell.strip():
                    continue
                parts = re.split(r"\s*[|,]\s*", cell.strip())
                for p in parts:
                    if not p:
                        continue
                    counts[p] = counts.get(p, 0) + 1
            # genre aggregation
            if genre_idx_opt is not None and genre_idx_opt < len(row):
                gcell = row[genre_idx_opt]
                if isinstance(gcell, str) and gcell.strip():
                    gparts = re.split(r"\s*[|,]\s*", gcell.strip())
                    for gp in gparts:
                        if not gp:
                            continue
                        genre_counts[gp] = genre_counts.get(gp, 0) + 1

        # top labels for this seed
        top_items = sorted(counts.items(), key=lambda x: (-x[1], x[0]))[:max(0, per_seed_top)]
        top_labels = [k for k, _ in top_items]
        per_seed_top_labels.append(top_labels)
        for k in top_labels:
            global_counts[k] = global_counts.get(k, 0) + 1
        # top genres for this seed
        top_g_items = sorted(genre_counts.items(), key=lambda x: (-x[1], x[0]))[:max(0, per_seed_top)]
        top_genres = [k for k, _ in top_g_items]
        per_seed_top_genres.append(top_genres)
        for k in top_genres:
            global_genre_counts[k] = global_genre_counts.get(k, 0) + 1

    final_top_labels = [k for k, _ in sorted(global_counts.items(), key=lambda x: (-x[1], x[0]))[:max(0, final_top)]]
    final_top_genres = [k for k, _ in sorted(global_genre_counts.items(), key=lambda x: (-x[1], x[0]))[:max(0, final_top)]]

    return {
        "seed_titles": seed_titles,
        "per_seed_top_labels": per_seed_top_labels,
        "per_seed_top_genres": per_seed_top_genres,
        "final_top_labels": final_top_labels,
        "final_top_genres": final_top_genres,
        "neighbors_indices": per_seed_neighbors,
        "per_seed_neighbor_titles": per_seed_neighbor_titles,
    }


def recommend_by_knn_multi_vectors(
    csv_path: str,
    seeds: List[object],
    k_neighbors: int = 3,
    per_seed_top: int = 3,
    final_top: int = 3,
    vector_cols: Optional[List[str]] = None,
    label_col_candidates: Optional[List[str]] = None,
    title_col_candidates: Optional[List[str]] = None,
) -> Dict[str, object]:
    """
    장르/무드/텍스쳐 벡터를 모두 사용하여 추천을 집계합니다.

    - 각 seed마다 vector_cols 내 각 벡터 컬럼에서 k개의 최근접 이웃을 구하고
      (코사인 유사도, 자기 자신 제외), 이웃들의 라벨(옷 스타일 등)을 집계하여
      시드별 상위 per_seed_top 라벨을 고릅니다.
    - 모든 시드의 결과(최대 3*per_seed_top)에서 다시 집계하여 최종 상위 final_top 라벨을 반환합니다.

    Returns dict with keys:
      "per_seed_top_labels": List[List[str]]
      "final_top_labels": List[str]
      "neighbors_indices": List[List[int]]  # per seed, combined neighbors (with possible duplicates)
    """
    if vector_cols is None:
        vector_cols = ["genre_vector", "mood_vector", "texture_vector"]
    if label_col_candidates is None:
        label_col_candidates = [
            "style_first", "style_second", "style_third",
            "outfit_style", "style", "clothes_style", "cloth_style",
            "패션", "스타일", "outfit"
        ]
    if title_col_candidates is None:
        title_col_candidates = ["title", "song", "name", "track", "곡명", "제목"]

    # Load CSV
    if not os.path.exists(csv_path):
        raise FileNotFoundError(csv_path)
    with open(csv_path, "r", encoding="utf-8-sig", newline="") as f:
        reader = csv.reader(f)
        rows = list(reader)
    if not rows:
        raise ValueError("빈 CSV")

    header = rows[0]
    data_rows = rows[1:]
    if not data_rows:
        raise ValueError("데이터 행이 없습니다")

    # Column indices
    vec_indices: List[int] = []
    for col in vector_cols:
        idx = _find_col_idx(header, [col])
        if idx is not None:
            vec_indices.append(idx)
    if not vec_indices:
        raise ValueError(f"벡터 열을 찾을 수 없습니다: {vector_cols}")

    title_idx = _find_col_idx(header, title_col_candidates)
    titles = [r[title_idx] if (title_idx is not None and title_idx < len(r)) else str(i) for i, r in enumerate(data_rows)]

    label_indices = _find_col_indices(header, label_col_candidates)
    # 장르 태그 열 (옵션)
    genre_idx_opt = _find_col_idx(header, ["genre_tags"])  # 없을 수 있음

    # Build matrices per vector column
    import numpy as _np
    matrices: List[_np.ndarray] = []
    valids: List[_np.ndarray] = []
    dims: List[int] = []

    for vi in vec_indices:
        vectors: List[Optional[List[float]]] = []
        for r in data_rows:
            cell = r[vi] if vi < len(r) else ""
            vectors.append(_parse_json_vector(cell))
        dim = 0
        for v in vectors:
            if isinstance(v, list) and len(v) > 0:
                dim = len(v)
                break
        if dim == 0:
            # 빈 열이면 스킵
            continue
        M = _np.zeros((len(vectors), dim), dtype=_np.float32)
        valid = _np.zeros((len(vectors),), dtype=_np.bool_)
        for i, v in enumerate(vectors):
            if isinstance(v, list) and len(v) == dim:
                M[i, :] = _np.array(v, dtype=_np.float32)
                valid[i] = True
        matrices.append(M)
        valids.append(valid)
        dims.append(dim)

    if not matrices:
        raise ValueError("유효한 벡터 행렬이 없습니다")

    def _cosine_sim_matrix_row(mat: _np.ndarray, idx: int) -> _np.ndarray:
        q = mat[idx]
        q_norm = _np.linalg.norm(q)
        if q_norm == 0:
            return _np.full((mat.shape[0],), -_np.inf, dtype=_np.float32)
        dot = mat @ q
        mat_norms = _np.linalg.norm(mat, axis=1)
        denom = (mat_norms * q_norm)
        with _np.errstate(divide='ignore', invalid='ignore'):
            sims = _np.where(denom > 0, dot / denom, -_np.inf)
        return sims

    # Resolve seeds → indices
    if len(seeds) != 3:
        raise ValueError("seeds는 3개여야 합니다")
    seed_indices: List[int] = []
    for s in seeds:
        idx = _resolve_seed_to_index(s, titles)
        if idx is None:
            raise ValueError(f"seed를 찾을 수 없습니다: {s}")
        seed_indices.append(idx)
    seed_titles: List[str] = [titles[i] for i in seed_indices]

    per_seed_neighbors: List[List[int]] = []
    per_seed_neighbor_titles: List[List[str]] = []
    per_seed_top_labels: List[List[str]] = []
    per_seed_top_genres: List[List[str]] = []
    global_counts: Dict[str, int] = {}
    global_genre_counts: Dict[str, int] = {}

    for si in seed_indices:
        combined_neighbors: List[int] = []
        for mat, valid in zip(matrices, valids):
            if si >= len(valid) or not valid[si]:
                continue
            sims = _cosine_sim_matrix_row(mat, si)
            if si < sims.shape[0]:
                sims[si] = -_np.inf  # exclude self
            nn_idx = _np.argsort(-sims)
            nn_idx = [int(i) for i in nn_idx if valid[int(i)]]
            nn_idx = nn_idx[:max(0, k_neighbors)]
            combined_neighbors.extend(nn_idx)
        per_seed_neighbors.append(combined_neighbors)
        per_seed_neighbor_titles.append([titles[ni] for ni in combined_neighbors])

        # Aggregate labels among combined neighbors (duplicates count multiple times)
        counts: Dict[str, int] = {}
        genre_counts: Dict[str, int] = {}
        for ni in combined_neighbors:
            if not label_indices:
                pass
            row = data_rows[ni]
            for li in label_indices:
                if li >= len(row):
                    continue
                cell = row[li]
                if not isinstance(cell, str) or not cell.strip():
                    continue
                parts = re.split(r"\s*[|,]\s*", cell.strip())
                for p in parts:
                    if not p:
                        continue
                    counts[p] = counts.get(p, 0) + 1
            # genre aggregation
            if genre_idx_opt is not None and genre_idx_opt < len(row):
                gcell = row[genre_idx_opt]
                if isinstance(gcell, str) and gcell.strip():
                    gparts = re.split(r"\s*[|,]\s*", gcell.strip())
                    for gp in gparts:
                        if not gp:
                            continue
                        genre_counts[gp] = genre_counts.get(gp, 0) + 1

        top_items = sorted(counts.items(), key=lambda x: (-x[1], x[0]))[:max(0, per_seed_top)]
        top_labels = [k for k, _ in top_items]
        per_seed_top_labels.append(top_labels)
        for k in top_labels:
            global_counts[k] = global_counts.get(k, 0) + 1
        # top genres for this seed
        top_g_items = sorted(genre_counts.items(), key=lambda x: (-x[1], x[0]))[:max(0, per_seed_top)]
        top_genres = [k for k, _ in top_g_items]
        per_seed_top_genres.append(top_genres)
        for k in top_genres:
            global_genre_counts[k] = global_genre_counts.get(k, 0) + 1

    final_top_labels = [k for k, _ in sorted(global_counts.items(), key=lambda x: (-x[1], x[0]))[:max(0, final_top)]]
    final_top_genres = [k for k, _ in sorted(global_genre_counts.items(), key=lambda x: (-x[1], x[0]))[:max(0, final_top)]]

    return {
        "seed_titles": seed_titles,
        "per_seed_top_labels": per_seed_top_labels,
        "per_seed_top_genres": per_seed_top_genres,
        "final_top_labels": final_top_labels,
        "final_top_genres": final_top_genres,
        "neighbors_indices": per_seed_neighbors,
        "per_seed_neighbor_titles": per_seed_neighbor_titles,
    }

# %%
if __name__ == "__main__":
    import argparse
    import sys

    parser = argparse.ArgumentParser(description="k-NN recommendation using genre/mood/texture vectors")
    parser.add_argument("--csv_path", default=CSV_PATH)
    parser.add_argument("--seeds", nargs="+", required=False, default=None, help="3 song titles or indices (0/1-based)")
    parser.add_argument("--k_neighbors", type=int, default=3)
    parser.add_argument("--per_seed_top", type=int, default=3)
    parser.add_argument("--final_top", type=int, default=3)
    parser.add_argument(
        "--vector_cols", nargs="+", default=["genre_vector", "mood_vector", "texture_vector"],
        help="Vector columns to use (default: genre/mood/texture)"
    )
    parser.add_argument("--label_cols", nargs="+", default=None, help="Label columns to aggregate (e.g., outfit_style)")
    parser.add_argument("--title_cols", nargs="+", default=None, help="Title columns (e.g., title song name track)")
    args, _unknown = parser.parse_known_args()

    seeds_arg = args.seeds if args.seeds is not None else []
    if len(seeds_arg) != 3:
        try:
            get_ipython  # type: ignore  # Colab/IPython 환경이면 기본값 사용
            print("[INFO] --seeds 미지정: Colab/IPython 환경으로 감지되어 기본 [1, 2, 3] 사용")
            seeds_arg = ["30", "50", "60"]
        except NameError:
            print("[ERROR] --seeds 는 정확히 3개를 지정해야 합니다. 예) --seeds 1 2 3")
            sys.exit(2)

    parsed_seeds = []
    for s in seeds_arg:
        try:
            parsed_seeds.append(int(s))
        except Exception:
            parsed_seeds.append(s)

    result = recommend_by_knn_multi_vectors(
        csv_path=args.csv_path,
        seeds=[15,22,36],
        k_neighbors=args.k_neighbors,
        per_seed_top=args.per_seed_top,
        final_top=args.final_top,
        vector_cols=args.vector_cols,
        label_col_candidates=args.label_cols,
        title_col_candidates=args.title_cols,
    )

    seed_titles = result.get("seed_titles", [])
    neighbor_titles = result.get("per_seed_neighbor_titles", [])
    per_seed_labels = result.get("per_seed_top_labels", [])
    per_seed_genres = result.get("per_seed_top_genres", [])
    final_labels = result.get("final_top_labels", [])
    final_genres = result.get("final_top_genres", [])

    print("[RESULT] Seeds:")
    for i, st in enumerate(seed_titles, 1):
        print(f"  Seed#{i} title: {st}")

    print("[RESULT] per-seed neighbors (titles):")
    for i, nt in enumerate(neighbor_titles, 1):
        print(f"  Seed#{i} neighbors: {nt}")

    print("[RESULT] per-seed top styles:")
    for i, labels in enumerate(per_seed_labels, 1):
        print(f"  Seed#{i}: {labels}")

    if per_seed_genres:
        print("[RESULT] per-seed top genres:")
        for i, genres in enumerate(per_seed_genres, 1):
            print(f"  Seed#{i}: {genres}")

    print(f"[RESULT] final top styles: {final_labels}")
    if final_genres:
        print(f"[RESULT] final top genres: {final_genres}")
# Out:
# [INFO] --seeds 미지정: Colab/IPython 환경으로 감지되어 기본 [1, 2, 3] 사용
# [RESULT] Seeds:
#   Seed#1 title: toxic till the end
#   Seed#2 title: 끝
#   Seed#3 title: 우리들의 블루스
# [RESULT] per-seed neighbors (titles):
#   Seed#1 neighbors: ['No Choice', '눈물참기', 'EXTRA', 'CaNdY LiEs', 'Magic Shop', 'Different Lives', '챔피언 (Feat. 정인)', '씨스루 (Feat. Zion.T, 개코 Of 다이나믹듀오)', 'FAMOUS']
#   Seed#2 neighbors: ['귀로', '서쪽 하늘', '마마', '마마', '귀로', '처음처럼', '귀로', '서쪽 하늘', 'I Fall In Love Too Easily']
#   Seed#3 neighbors: ['등대', '서툰 이별을 하려해 (Feat.전상근)', 'Do You Hear What I Hear', '...사랑했잖아...(2024)', '우리 왜 헤어져야 해 (여름날 우리 X 전상근)', 'my story', '서툰 이별을 하려해 (Feat.전상근)', '우리 왜 헤어져야 해 (여름날 우리 X 전상근)', '등대']
# [RESULT] per-seed top styles:
#   Seed#1: ['미니멀 / Minimal Fashion', '캐주얼 / Casual', '스트릿 / Street Fashion']
#   Seed#2: ['캐주얼 / Casual', '시크 / Chic Fashion', '미니멀 / Minimal Fashion']
#   Seed#3: ['캐주얼 / Casual', '스트릿 / Street Fashion', '미니멀 / Minimal Fashion']
# [RESULT] per-seed top genres:
#   Seed#1: ['Indie Pop', 'Pop', 'Soul']
#   Seed#2: ['Ambient', 'Soul', 'Blues']
#   Seed#3: ['Pop', 'Soul', 'Country']
# [RESULT] final top styles: ['미니멀 / Minimal Fashion', '캐주얼 / Casual', '스트릿 / Street Fashion']
# [RESULT] final top genres: ['Soul', 'Pop', 'Ambient']

# %%
# !python main.py --seeds 1 2 3
# Out:
# python3: can't open file '/content/main.py': [Errno 2] No such file or directory

# %%
# Out:
# [TAGS] #1: 001 - JAY-Z - NEW YORK (CONCEPT DE PARIS) (Feat. Gil Scott-Heron).mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #2: 002 - Lady Gaga - Die With A Smile.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #3: 003 - Fly By Midnight - Different Lives.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #4: 004 - BOYNEXTDOOR - 오늘만 I LOVE YOU.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #5: 005 - Crush - 가끔.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #6: 006 - syudou - Call Boy.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #7: 007 - 【初音ミク】コールボーイ【syudou】.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #8: 008 - Medusa - 뱀(Snake).mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #9: 009 - Motorhead - The Chase Is Better Than the Catch (Live at Sporthalle, Heilbronn, 29th December 1984).mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #10: 010 - Yuuri - BETELGEUSE.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #11: 011 - jazzyfact - vibra.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #12: 012 - 조째즈 - 모르시나요(PROD.로코베리).mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #13: 013 - 창모 (CHANGMO) - PURE RAGE (Remix) (Feat. Paul Blanco, KHAN, XWALLY, Coogie, Tray B).mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #14: 014 - 세븐틴 (SEVENTEEN) - 청춘찬가.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #15: 015 - ALLDAY PROJECT - Famous.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #16: 016 - 로제 (ROSÉ) - toxic till the end.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #17: 017 - 오마이걸 (OH MY GIRL) - Dolphin.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #18: 018 - Calvin Harris - Feels (Feat. Pharrell Williams, Katy Perry, Big Sean).mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #19: 019 - LUCY - 개화 (Flowering).mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #20: 020 - Post Malone - Sunflower (Spider-Man Into the Spider-Verse).mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #21: 021 - 제니 (JENNIE) - like JENNIE.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #22: 022 - ALLDAY PROJECT - FAMOUS.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #23: 023 - 권진아 - 끝.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #24: 024 - 세븐틴 (SEVENTEEN) - THUNDER.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #25: 025 - Nightwish - Wish I Had An Angel.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #26: 026 - Prok - Medallo.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #27: 027 - 권진아 - 재회.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #28: 028 - 조승우 - 꽃이 피고 지듯이.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #29: 029 - Panic! At The Disco - Victorious.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #30: 030 - 아일(I'll) - 12월 (Hate December).mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #31: 031 - 수우 (soowoo) - stay with me (Feat. dori).mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #32: 032 - 유다빈밴드 - 항해.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #33: 033 - 프라이머리 - (물음표) (Feat. 최자 Of 다이나믹듀오, Zion.T).mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #34: 034 - C JAMM - puzzle.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #35: 035 - 나얼 - 귀로.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #36: 036 - 하현상 - Close.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #37: 037 - 임영웅 - 우리들의 블루스.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #38: 038 - 다이나믹 듀오 - 죽일 놈 (Guilty).mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #39: 039 - 프라이머리 - 씨스루 (Feat. Zion.T, 개코 Of 다이나믹듀오).mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #40: 040 - 정은지 - 하늘바라기 (Feat. 하림).mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #41: 041 - 경서예지 - 다정히 내 이름을 부르면.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #42: 042 - aespa - Dirty Work.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #43: 043 - YB (윤도현 밴드) - 흰수염고래.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #44: 044 - 중식이 - 나는 반딧불.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #45: 045 - 장윤정 - 어부바.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #46: 046 - DAY6 (데이식스) - Welcome to the Show.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #47: 047 - Anzunokumo - Drowing.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #48: 048 - The Weeknd - Timeless.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #49: 049 - 빈지노 (Beenzino) - 젖고있어.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #50: 050 - 이승철 - 서쪽 하늘.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #51: 051 - 황가람 - 미치게 그리워서.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #52: 052 - Frank Ocean - Pink + White.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #53: 053 - Against The Current - Legends Never Die.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #54: 054 - 고추잠자리 - 너라는 별.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #55: 055 - 고경표 - ...사랑했잖아...(2024).mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #56: 056 - Ed Sheeran - Sapphire.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #57: 057 - DPR LIVE - Jasmine.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #58: 058 - Sam Smith - Too Good At Goodbyes.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #59: 059 - 보이넥스트도어 - 123-78.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #60: 060 - Chris Stapleton - Bad As I Used To Be (From F1® The Movie).mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #61: 061 - 빈지노 (Beenzino) - TRAIN.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #62: 062 - 릴러말즈 (Leellamarz) - 거리에서 (Feat. ASH ISLAND).mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #63: 063 - 헤이즈 (Heize) - Jenga (Feat. Gaeko).mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #64: 064 - Damnino David - Next Summer.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #65: 065 - Billie Eilish - GOLDWING.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #66: 066 - WELOVE - 하나님의 사랑이.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #67: 067 - 에이핑크 - MR.CHU.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #68: 068 - Xdinary Heroes - FiRE (My Sweet Misery).mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #69: 069 - Christian Kuria - Deep Green.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #70: 070 - Lauv - Breathe.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #71: 071 - 태연 (TAEYEON) - 그대라는 시.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #72: 072 - Fetty Wap - Again.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #73: 073 - Ray Charles - Hit The Road Jack.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #74: 074 - 김필선 - 마마.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #75: 075 - Ella Fitzgerald - Misty.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #76: 076 - The Weeknd - Blinding Lights.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #77: 077 - MS20pow - Exo Circuit Drift.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #78: 078 - aespa - Dirty Work.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #79: 079 - YMO - BEHIND THE MASK (YMO LIVE AT THE GREEK THEATRE 08 04 1979).mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #80: 080 - 이세계 - 낭만젊음사랑.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #81: 081 - Chicago - Hard To Say I'm Sorry.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #82: 082 - Ariana Grande - Problem (Feat. Iggy Azalea).mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #83: 083 - 리쌍 - 챔피언 (Feat. 정인).mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #84: 084 - sunny day real estate - nan.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #85: 085 - 전소미 - EXTRA.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #86: 086 - 검정치마 - 기다린 만큼, 더.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #87: 087 - 브라운아이드 소울 - my story.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #88: 088 - 한요한 - it's you.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #89: 089 - ＂Una voce poco fa＂ Rosina, Il Barbiere di Siviglia, ROSSINI - Melody LOULEDJIAN.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #90: 090 - 수연이 - Selfish.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #91: 091 - Daniel caesar - Best part.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #92: 092 - Chet Baker - I Fall In Love Too Easily.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #93: 093 - 윤토벤 - 서툰 이별을 하려해 (Feat.전상근).mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #94: 094 - 엠씨더맥스 (M.C the MAX) - 사계 (하루살이).mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #95: 095 - ALLDAY PROJECT - FAMOUS.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #96: 096 - almost monday - sunburn.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #97: 097 - ALLDAY PROJECT - FAMOUS.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #98: 098 - nan - nan.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #99: 099 - Benson Boone - Beautiful Things.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #100: 100 - 식케이 (Sik-K) - LOV3 (Feat. Bryan Chase, Okasian).mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #101: 101 - Jenevieve - CaNdY LiEs.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #102: 102 - 식케이 (Sik-K) - LOV3 (Feat. Bryan Chase, Okasian).mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #103: 103 - wave to earth - pueblo.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #104: 104 - 잔나비 - 달.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #105: 105 - 식케이 (Sik-K) - PUBLIC ENEMY (Feat. 노윤하, Wuuslime).mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #106: 106 - 모세 - 사랑인걸.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #107: 107 - 8-Bit Arcade - Supersonic (8-Bit Fromis 9 Emulation).mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #108: 108 - ASU - ブルーナイトダーリン - ブルーナイトダーリン.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #109: 109 - QWER - 눈물참기.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #110: 110 - Fly By Midnight - No Choice.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #111: 111 - DAY6 (데이식스) - 예뻤어.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #112: 112 - Fear, and Loathing in Las Vegas - Party Boys.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #113: 113 - QWER - 눈물참기.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #114: 114 - MEOVV (미야오) - DROP TOP.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #115: 115 - 다이나믹 듀오 - 죽일 놈 (Guilty).mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #116: 116 - Jordan Ward - FAMJAM4000.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #117: 117 - LUCY - 떼굴떼굴.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #118: 118 - Olivia Rodrigo - drivers license.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #119: 119 - 방탄소년단 - Pied Piper.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #120: 120 - The Struts - Roll Up.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #121: 121 - 이무진 - 뱁새.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #122: 122 - Black Eyed Peas - Pump It.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #123: 123 - 하현상 - 등대.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #124: 124 - 백예린 (Yerin Baek) - Datoom.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #125: 125 - 박효신 - 야생화.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #126: 126 - 엔플라잉 (N.Flying) - Autumn Dream.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #127: 127 - 죠지 - Boat.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #128: 128 - 프라이머리 - 마네퀸 (Feat. Beenzino, 수란).mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #129: 129 - NMIXX - PAXXWORD.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #130: 130 - 전상근 - 우리 왜 헤어져야 해 (여름날 우리 X 전상근).mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #131: 131 - 장윤정 - 목포행 완행열차.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #132: 132 - WOODZ - Drowning.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #133: 133 - 박다혜 - 시작의 아이 ❍.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #134: 134 - 고추잠자리 - 작은 봄.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #135: 135 - 박재범 - 곁에 있어주길.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #136: 136 - BOYNEXTDOOR - I Feel Good.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #137: 137 - The Weeknd - Earned It (Fifty Shades Of Grey) (Marian Hill Remix).mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #138: 138 - 방탄소년단 - Magic Shop.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #139: 139 - Wayburn Dean - Do You Hear What I Hear.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #140: 140 - Fred again.. - Victory Lap.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #141: 141 - Lil Tecca - Dark Thoughts.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #142: 142 - Childish Gambino - Redbone.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #143: 143 - 최유리 - 숲.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #144: 144 - The Runners - Give Life Back to Music (122 BPM).mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #145: 145 - 심규선 - 화조도 花鳥圖.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #146: 146 - America - You Can Do Magic.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #147: 147 - 터치드(TOUCHED) - Highlight.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #148: 148 - 싸이 (PSY) - 77학개론 (Feat. 리쌍, 김진표).mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #149: 149 - American Football - Never Meant (Live in Los Angeles).mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #150: 150 - Hearts2Hearts (하츠투하츠) - STYLE.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #151: 151 - 안세권 - Un Amore Cosi Grande.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #152: 152 - Cosmic Boy - Can I Love (Feat. 유라(youra), Meego).mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #153: 153 - 엠씨더맥스 (M.C the MAX) - 처음처럼.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #154: 154 - ALLDAY PROJECT - WICKED.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #155: 155 - Abe Parker - Live, Laugh, Love.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #156: 156 - Xdinary Heroes - Save me.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #157: 157 - DAY6 (데이식스) - Shoot Me.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #158: 158 - HAAN&CHAN - 쌘척.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #159: 159 - Effie - down.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #160: 160 - 염따 - IE러니.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #161: 161 - QWER - 눈물참기.mp3 → G:4 M:4 T:4 + vectors
# [TAGS] #162: 162 - BIG Naughty (서동현) - INFJ (Feat. B.I, 방예담).mp3 → G:4 M:4 T:4 + vectors
# [WRITE] 태그 열 업데이트 완료 → /content/drive/MyDrive/graduateproject/data/songs_out_final.csv
